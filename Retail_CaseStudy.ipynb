# %%
import pandas as pd

# %%
Customer=pd.read_csv(r'C:\Users\ADMIN\Downloads\Customer.csv')

# %% [raw]
# Customer

# %%
Customer
# Out:
#       customer_Id       DOB Gender  city_code
# 0          268408    2-1-70      M        4.0
# 1          269696    7-1-70      F        8.0
# 2          268159    8-1-70      F        8.0
# 3          270181   10-1-70      F        2.0
# 4          268073   11-1-70      M        1.0
# ...           ...       ...    ...        ...
# 5642       274474  19-12-92      M        2.0
# 5643       267666  24-12-92      M        6.0
# 5644       270476  25-12-92      F        3.0
# 5645       269626  27-12-92      F        5.0
# 5646       274308  29-12-92      F        5.0
#
# [5647 rows x 4 columns]

# %%
Product_hierarchy = pd.read_csv(r'C:\Users\ADMIN\Downloads\prod_cat_info.csv')

# %%
Product_hierarchy
# Out:
#     prod_cat_code          prod_cat  prod_sub_cat_code          prod_subcat
# 0               1          Clothing                  4                 Mens
# 1               1          Clothing                  1                Women
# 2               1          Clothing                  3                 Kids
# 3               2          Footwear                  1                 Mens
# 4               2          Footwear                  3                Women
# 5               2          Footwear                  4                 Kids
# 6               3       Electronics                  4              Mobiles
# 7               3       Electronics                  5            Computers
# 8               3       Electronics                  8  Personal Appliances
# 9               3       Electronics                  9              Cameras
# 10              3       Electronics                 10      Audio and video
# 11              4              Bags                  1                 Mens
# 12              4              Bags                  4                Women
# 13              5             Books                  7              Fiction
# 14              5             Books                 12             Academic
# 15              5             Books                 10          Non-Fiction
# 16              5             Books                 11             Children
# 17              5             Books                  3               Comics
# 18              5             Books                  6                  DIY
# 19              6  Home and kitchen                  2           Furnishing
# 20              6  Home and kitchen                 10              Kitchen
# 21              6  Home and kitchen                 11                 Bath
# 22              6  Home and kitchen                 12                Tools

# %%
Transaction = pd.read_csv(r'C:\Users\ADMIN\Downloads\Transactions.csv')
Transaction
# Out:
#        transaction_id  cust_id   tran_date  prod_subcat_code  prod_cat_code  \
# 0         80712190438   270351  28-02-2014                 1              1
# 1         29258453508   270384  27-02-2014                 5              3
# 2         51750724947   273420  24-02-2014                 6              5
# 3         93274880719   271509  24-02-2014                11              6
# 4         51750724947   273420  23-02-2014                 6              5
# ...               ...      ...         ...               ...            ...
# 23048     94340757522   274550  25-01-2011                12              5
# 23049     89780862956   270022  25-01-2011                 4              1
# 23050     85115299378   271020  25-01-2011                 2              6
# 23051     72870271171   270911  25-01-2011                11              5
# 23052     77960931771   271961  25-01-2011                11              5
#
#        Qty  Rate      Tax  total_amt Store_type
# 0       -5  -772  405.300  -4265.300     e-Shop
# 1       -5 -1497  785.925  -8270.925     e-Shop
# 2       -2  -791  166.110  -1748.110   TeleShop
# 3       -3 -1363  429.345  -4518.345     e-Shop
# 4       -2  -791  166.110  -1748.110   TeleShop
# ...    ...   ...      ...        ...        ...
# 23048    1  1264  132.720   1396.720     e-Shop
# 23049    1   677   71.085    748.085     e-Shop
# 23050    4  1052  441.840   4649.840        MBR
# 23051    3  1142  359.730   3785.730   TeleShop
# 23052    1   447   46.935    493.935   TeleShop
#
# [23053 rows x 10 columns]

# %%
Customer_Trans=pd.merge(left=Customer,
                        right=Transaction,
                        left_on='customer_Id',
                        right_on='cust_id',
                        how='inner',
                       )

# %%
Customer_Trans.shape
# Out:
# (23053, 14)

# %%
Customer_Final=pd.merge(left=Customer_Trans,
                        right=Product_hierarchy,
                        left_on='prod_cat_code',
                        right_on='prod_cat_code',
                        how='inner'
                       )

# %%
Customer_Final
# Out:
#        customer_Id       DOB Gender  city_code  transaction_id  cust_id  \
# 0           268408    2-1-70      M        4.0     87243835584   268408
# 1           268408    2-1-70      M        4.0     87243835584   268408
# 2           268408    2-1-70      M        4.0     87243835584   268408
# 3           268408    2-1-70      M        4.0     87243835584   268408
# 4           268408    2-1-70      M        4.0     87243835584   268408
# ...            ...       ...    ...        ...             ...      ...
# 99288       274308  29-12-92      F        5.0     58160544337   274308
# 99289       274308  29-12-92      F        5.0     58160544337   274308
# 99290       274308  29-12-92      F        5.0     58160544337   274308
# 99291       274308  29-12-92      F        5.0     58160544337   274308
# 99292       274308  29-12-92      F        5.0     58160544337   274308
#
#         tran_date  prod_subcat_code  prod_cat_code  Qty  Rate      Tax  \
# 0      13-01-2014                 7              5    5   187   98.175
# 1      13-01-2014                 7              5    5   187   98.175
# 2      13-01-2014                 7              5    5   187   98.175
# 3      13-01-2014                 7              5    5   187   98.175
# 4      13-01-2014                 7              5    5   187   98.175
# ...           ...               ...            ...  ...   ...      ...
# 99288    4/7/2012                12              5    5   588  308.700
# 99289    4/7/2012                12              5    5   588  308.700
# 99290    4/7/2012                12              5    5   588  308.700
# 99291    4/7/2012                12              5    5   588  308.700
# 99292    4/7/2012                12              5    5   588  308.700
#
#        total_amt Store_type prod_cat  prod_sub_cat_code  prod_subcat
# 0       1033.175   TeleShop    Books                  7      Fiction
# 1       1033.175   TeleShop    Books                 12     Academic
# 2       1033.175   TeleShop    Books                 10  Non-Fiction
# 3       1033.175   TeleShop    Books                 11     Children
# 4       1033.175   TeleShop    Books                  3       Comics
# ...          ...        ...      ...                ...          ...
# 99288   3248.700     e-Shop    Books                 12     Academic
# 99289   3248.700     e-Shop    Books                 10  Non-Fiction
# 99290   3248.700     e-Shop    Books                 11     Children
# 99291   3248.700     e-Shop    Books                  3       Comics
# 99292   3248.700     e-Shop    Books                  6          DIY
#
# [99293 rows x 17 columns]

# %%
Customer_Final.dtypes
# Out:
# customer_Id            int64
# DOB                   object
# Gender                object
# city_code            float64
# transaction_id         int64
# cust_id                int64
# tran_date             object
# prod_subcat_code       int64
# prod_cat_code          int64
# Qty                    int64
# Rate                   int64
# Tax                  float64
# total_amt            float64
# Store_type            object
# prod_cat              object
# prod_sub_cat_code      int64
# prod_subcat           object
# dtype: object

# %%
Customer_Final.head(10)
# Out:
#    customer_Id     DOB Gender  city_code  transaction_id  cust_id   tran_date  \
# 0       268408  2-1-70      M        4.0     87243835584   268408  13-01-2014
# 1       268408  2-1-70      M        4.0     87243835584   268408  13-01-2014
# 2       268408  2-1-70      M        4.0     87243835584   268408  13-01-2014
# 3       268408  2-1-70      M        4.0     87243835584   268408  13-01-2014
# 4       268408  2-1-70      M        4.0     87243835584   268408  13-01-2014
# 5       268408  2-1-70      M        4.0     87243835584   268408  13-01-2014
# 6       268408  2-1-70      M        4.0     16197868036   268408  16-12-2013
# 7       268408  2-1-70      M        4.0     16197868036   268408  16-12-2013
# 8       268408  2-1-70      M        4.0     16197868036   268408  12/12/2013
# 9       268408  2-1-70      M        4.0     16197868036   268408  12/12/2013
#
#    prod_subcat_code  prod_cat_code  Qty  Rate      Tax  total_amt  \
# 0                 7              5    5   187   98.175   1033.175
# 1                 7              5    5   187   98.175   1033.175
# 2                 7              5    5   187   98.175   1033.175
# 3                 7              5    5   187   98.175   1033.175
# 4                 7              5    5   187   98.175   1033.175
# 5                 7              5    5   187   98.175   1033.175
# 6                 1              4   -5  -210  110.250  -1160.250
# 7                 1              4   -5  -210  110.250  -1160.250
# 8                 1              4    5   210  110.250   1160.250
# 9                 1              4    5   210  110.250   1160.250
#
#        Store_type prod_cat  prod_sub_cat_code  prod_subcat
# 0        TeleShop    Books                  7      Fiction
# 1        TeleShop    Books                 12     Academic
# 2        TeleShop    Books                 10  Non-Fiction
# 3        TeleShop    Books                 11     Children
# 4        TeleShop    Books                  3       Comics
# 5        TeleShop    Books                  6          DIY
# 6  Flagship store     Bags                  1         Mens
# 7  Flagship store     Bags                  4        Women
# 8  Flagship store     Bags                  1         Mens
# 9  Flagship store     Bags                  4        Women

# %%
import numpy as np
Data_min = Customer_Final['total_amt'].min()
Data_max = Customer_Final['total_amt'].max()
Data_q1  = np.percentile(Customer_Final.total_amt,25)
median  = np.percentile(Customer_Final.total_amt,50)
Data_q3  = np.percentile(Customer_Final.total_amt,75)
print('Min = ',Data_min)
print('Max = ',Data_max)
print('Median = ',median)
print('Q1 = ',Data_q1)
print('Q3 = ',Data_q3)
# Out:
# Min =  -8270.925
# Max =  8287.5
# Median =  1761.37
# Q1 =  762.45
# Q3 =  3585.725

# %%
Data_min=Customer_Final['total_amt'].min()
Data_max=Customer_Final['total_amt'].max()
Data_q1=np.percentile(Customer_Final.total_amt,25)
median=np.percentile(Customer_Final.total_amt,50)
Data_q3=np.percentile(Customer_Final.total_amt,75)

# %%
print(f"Min : {Data_min}")
print(f"Max : {Data_max}")
print(f"Median : {median}")
print('Q1 = ', Data_q1)
print('Q3 = ',Data_q3)
# Out:
# Min : -8270.925
# Max : 8287.5
# Median : 1761.37
# Q1 =  762.45
# Q3 =  3585.725
